# %%
from tensorboardX import SummaryWriter
import pandas as pd
import numpy as np
import torch
import japanize_matplotlib

# %%
# !pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ## わからないを含む意見の可視化

# %%
op = ["I agree with the idea that 'husbands should work outside the home and wives should take care of the home'.", 
"I rather agree with the idea that 'husbands should work outside the home and wives should take care of the home'.", 
"I rather disagree with the idea that 'husbands should work outside the home and wives should take care of the home'.", 
"I disagree with the idea that 'husbands should work outside the home and wives should take care of the home'.",
"I don't know."]

# %%
gend = model.encode(op)

writer = SummaryWriter()
weights = gend

# weights = weights[:500]
labels = op

writer.add_embedding(torch.FloatTensor(weights), metadata=labels)

# %% [markdown]
# ### 主成分分析
# https://towardsdatascience.com/visualization-of-word-embedding-vectors-using-gensim-and-pca-8f592a5d3354

# %%
weights.shape
# Out:
# (5, 384)

# %%
vec = weights.tolist()
print(len(vec[0]), len(vec))
# Out:
# 384 5

# %%
import pandas as pd

df1 = pd.DataFrame(op, columns=['sentence'])
df1
# Out:
#                                             sentence
# 0  I agree with the idea that 'husbands should wo...
# 1  I rather agree with the idea that 'husbands sh...
# 2  I rather disagree with the idea that 'husbands...
# 3  I disagree with the idea that 'husbands should...
# 4                                      I don't know.

# %%
df = pd.DataFrame((vec[i] for i in range(0, 5)), index=df1)
df
# Out:
#                                                          0         1    \
# (I agree with the idea that 'husbands should wo... -0.027554  0.039380
# (I rather agree with the idea that 'husbands sh... -0.020657  0.048408
# (I rather disagree with the idea that 'husbands... -0.008303  0.039548
# (I disagree with the idea that 'husbands should... -0.008475  0.036140
# (I don't know.,)                                   -0.038426 -0.037329
#
#                                                          2         3    \
# (I agree with the idea that 'husbands should wo...  0.027832 -0.037115
# (I rather agree with the idea that 'husbands sh...  0.019616 -0.035483
# (I rather disagree with the idea that 'husbands...  0.011782 -0.029389
# (I disagree with the idea that 'husbands should...  0.027747 -0.022028
# (I don't know.,)                                   -0.001455  0.007310
#
#                                                          4         5    \
# (I agree with the idea that 'husbands should wo...  0.021701  0.017040
# (I rather agree with the idea that 'husbands sh...  0.038134 -0.005517
# (I rather disagree with the idea that 'husbands...  0.029074 -0.014805
# (I disagree with the idea that 'husbands should...  0.013961 -0.012958
# (I don't know.,)                                    0.041105  0.062348
#
#                                                          6         7    \
# (I agree with the idea that 'husbands should wo...  0.080843 -0.093988
# (I rather agree with the idea that 'husbands sh...  0.047715 -0.083218
# (I rather disagree with the idea that 'husbands...  0.034313 -0.089611
# (I disagree with the idea that 'husbands should...  0.069456 -0.111053
# (I don't know.,)                                    0.134133 -0.079533
#
#                                                          8         9    ...  \
# (I agree with the idea that 'husbands should wo... -0.143284 -0.018548  ...
# (I rather agree with the idea that 'husbands sh... -0.103717 -0.012229  ...
# (I rather disagree with the idea that 'husbands... -0.101908 -0.007050  ...
# (I disagree with the idea that 'husbands should... -0.135607 -0.015679  ...
# (I don't know.,)                                   -0.017238  0.002034  ...
#
#                                                          374       375  \
# (I agree with the idea that 'husbands should wo...  0.099616 -0.065479
# (I rather agree with the idea that 'husbands sh...  0.109128 -0.058331
# (I rather disagree with the idea that 'husbands...  0.103397 -0.054568
# (I disagree with the idea that 'husbands should...  0.092088 -0.063725
# (I don't know.,)                                    0.063609 -0.071707
#
#                                                          376       377  \
# (I agree with the idea that 'husbands should wo...  0.017474 -0.058809
# (I rather agree with the idea that 'husbands sh... -0.004003 -0.072889
# (I rather disagree with the idea that 'husbands... -0.008702 -0.087694
# (I disagree with the idea that 'husbands should...  0.004274 -0.074143
# (I don't know.,)                                    0.067865 -0.008854
#
#                                                          378       379  \
# (I agree with the idea that 'husbands should wo... -0.050389  0.019873
# (I rather agree with the idea that 'husbands sh... -0.051409  0.026802
# (I rather disagree with the idea that 'husbands... -0.055161  0.015066
# (I disagree with the idea that 'husbands should... -0.055228 -0.000729
# (I don't know.,)                                    0.026192  0.028387
#
#                                                          380       381  \
# (I agree with the idea that 'husbands should wo... -0.000510  0.070249
# (I rather agree with the idea that 'husbands sh...  0.010214  0.056063
# (I rather disagree with the idea that 'husbands...  0.011247  0.060177
# (I disagree with the idea that 'husbands should...  0.007074  0.067364
# (I don't know.,)                                    0.025203  0.053095
#
#                                                          382       383
# (I agree with the idea that 'husbands should wo...  0.008544  0.063030
# (I rather agree with the idea that 'husbands sh...  0.003143  0.057876
# (I rather disagree with the idea that 'husbands...  0.016067  0.064142
# (I disagree with the idea that 'husbands should...  0.012397  0.069519
# (I don't know.,)                                   -0.003148 -0.103636
#
# [5 rows x 384 columns]

# %%
#Computing the correlation matrix
X_corr = df.corr()

#Computing eigen values and eigen vectors
values,vectors = np.linalg.eig(X_corr)

#Sorting the eigen vectors coresponding to eigen values in descending order
args = (-values).argsort()
values = vectors[args]
vectors = vectors[:, args]

#Taking first 2 components which explain maximum variance for projecting
new_vectors = vectors[:,:2]

#Projecting it onto new dimesion with 2 axis
neww_X = np.real(np.dot(vec, new_vectors))
neww_X
# Out:
# array([[-0.57462425, -0.11817785],
#        [-0.5932243 , -0.02569687],
#        [-0.58693364,  0.12600551],
#        [-0.57230556,  0.08651021],
#        [ 0.59259639, -0.01428951]])

# %%
# np.linalg ver
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.scatter(neww_X[:,0],neww_X[:,1],linewidths=10,color='yellow')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.2, 0.2)
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
# plt.title("Word Embedding Space",size=20)
vocab=op
for i, word in enumerate(vocab):
  plt.annotate(word,xy=(neww_X[i,0],neww_X[i,1]))

plt.savefig('5_pca.png')

# %%
# np.linalg ver
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.scatter(neww_X[:,0],neww_X[:,1], linewidths=10, color='yellow')
plt.xlim(-0.2, 0.2)
plt.ylim(-0.2, 0.2)
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
# plt.title("Word Embedding Space",size=20)
jp = ['賛成', 'やや賛成', 'やや反対', '反対']
for i, word in enumerate(jp):
  plt.annotate(word,xy=(neww_X[i,0],neww_X[i,1]))

plt.subplots_adjust(left=0.15, right=0.95, bottom=0.1, top=0.95)
plt.savefig('5_pca_jp.png')

# %% [markdown]
# #### 寄与率計算
# https://qiita.com/nmmg0031785/items/0ab3f8cdf22f5f0ea273

# %%
# 共分散行列(covariance matrix)
covmatrix = np.cov(weights.T)

# 固有値, 固有ベクトルを求める
eig = np.linalg.eig(covmatrix)[0]
eigvec = np.linalg.eig(covmatrix)[1]

# 昇順に並べ替え
idx = np.argsort(eig)[::-1]
eig = eig[idx]
eigvec = eigvec[idx]

# 主成分得点
pcacor = np.dot(weights, eigvec)

# 寄与率
cr = eig/sum(eig)

# %%
import matplotlib.pyplot as plt

## 累積寄与率をプロット
ccr = np.cumsum(cr)[:3]
lb = ["PC{}".format(i+1) for i in range(3)]

fig = plt.figure(figsize=(6,3)) #,dpi=320)
ax = fig.add_subplot(111)
ax.bar(lb, ccr, label="累積寄与率")
plt.ylabel("cumulative contribution rate")
# plt.savefig('contri_rate.png')
# Out:
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:762: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.asarray(points, float)
# Text(0, 0.5, 'cumulative contribution rate')

# %%
# データ中心と主成分軸を計算
ave = np.mean(weights, axis=0)
dpt = ave + eigvec

# プロット
fig = plt.figure(figsize=(4,4)) #,dpi=320)
ax = fig.add_subplot(111)
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.xlabel("x1")
plt.ylabel("x2")

ax.scatter(weights[:,0], weights[:,1], alpha=0.4)
ax.scatter(ave[0], ave[1], marker="*", color="red")
for i in range(2):
    ax.plot([ave[0], dpt[0,i]], [ave[1], dpt[1,i]],
            color="red", linewidth=1)
    ax.text(dpt[0,i], dpt[1,i], "pc{}".format(i+1))
# Out:
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cbook\__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\text.py:692: ComplexWarning: Casting complex values to real discards the imaginary part
#   posx = float(self.convert_xunits(self._x))
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\text.py:693: ComplexWarning: Casting complex values to real discards the imaginary part
#   posy = float(self.convert_yunits(self._y))
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\text.py:832: ComplexWarning: Casting complex values to real discards the imaginary part
#   x = float(self.convert_xunits(self._x))
# C:\Users\so030\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\text.py:833: ComplexWarning: Casting complex values to real discards the imaginary part
#   y = float(self.convert_yunits(self._y))

# %% [markdown]
# #### sklearnによる確かめ
# https://chokkan.github.io/mlnote/unsupervised/03pca.html#id7

# %% [markdown]
# ##### 再現バージョン

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X = weights
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[-1.61703043e-02, -5.67248799e-02, -1.66683123e-02,
#          2.77544539e-02,  1.09961228e-02,  4.83479686e-02,
#          5.55416793e-02,  1.06868017e-02,  7.48464391e-02,
#          1.10712266e-02,  4.10480872e-02, -9.85708088e-02,
#         -5.21468604e-03, -2.85751913e-02, -3.30952257e-02,
#         -6.56566247e-02, -6.16695778e-03, -9.92673170e-03,
#         -5.88425435e-02,  2.01849104e-03,  3.65952328e-02,
#         -2.77115311e-02, -3.89885856e-03, -3.52013856e-03,
#          4.42293435e-02,  3.24954540e-02, -5.51166199e-02,
#          7.33679608e-02,  4.40898873e-02, -1.12135783e-01,
#         -7.40748867e-02,  9.27401707e-03, -2.04293616e-02,
#         -9.24879313e-03, -3.95892896e-02,  2.07695980e-02,
#          6.69571385e-02, -5.65545522e-02,  3.52793513e-03,
#          4.95639816e-02,  7.12391164e-04, -7.03834742e-02,
#         -3.59194688e-02,  2.31707115e-02,  3.34917642e-02,
#         -7.27660581e-03, -2.08716840e-02,  1.00160077e-01,
#          2.65549980e-02, -3.40550281e-02, -2.59851888e-02,
#         -2.23130751e-02,  6.59410805e-02,  1.88395344e-02,
#         -2.89784465e-02, -4.54451554e-02,  7.77027607e-02,
#          2.45479830e-02, -1.93208139e-02,  1.67055819e-02,
#         -7.10310265e-02, -1.75577716e-03, -2.65704710e-02,
#          4.17101495e-02,  1.18378205e-02,  1.93425864e-02,
#          8.07019137e-03, -7.18111992e-02,  3.87852564e-02,
#         -5.11356145e-02,  7.02925101e-02, -9.44776237e-02,
#          2.97827292e-02,  7.56161101e-03,  1.51315099e-02,
#          9.35214804e-04,  3.75175104e-02,  1.11735314e-02,
#          9.07185674e-02,  4.85561788e-02,  7.13416636e-02,
#         -8.24336931e-02, -1.02437465e-02, -2.17579324e-02,
#          3.23640183e-02, -1.47997597e-02,  1.17566124e-01,
#          9.81560070e-03, -1.55973807e-01,  2.02635843e-02,
#          1.16433740e-01,  9.32323188e-02, -3.04826982e-02,
#          2.63120746e-04,  1.17143290e-02, -3.01519339e-03,
#         -6.17914647e-03, -5.04747091e-04,  1.21616155e-01,
#          6.77420571e-02,  2.76330616e-02, -1.20068027e-03,
#         -4.67657484e-02, -5.15025705e-02, -2.91683199e-03,
#         -1.15115233e-01, -2.81778779e-02,  1.87521242e-02,
#          4.33408730e-02, -4.74747532e-04,  2.27603540e-02,
#         -5.60911186e-03,  4.02670773e-03, -7.33699203e-02,
#         -9.20352759e-04,  3.78576592e-02, -7.58946687e-02,
#          6.37113443e-03,  1.72290322e-03,  2.30142474e-02,
#         -2.96211541e-02, -4.52424353e-03, -3.40697393e-02,
#         -3.85747477e-02, -1.17947832e-01,  6.34314567e-02,
#         -1.15281671e-01, -4.32563627e-33,  8.96401107e-02,
#         -6.68999106e-02, -2.26811483e-03, -9.26491152e-03,
#         -1.33047365e-02,  1.38353156e-02, -2.31878199e-02,
#         -7.30101997e-03, -8.52064416e-02, -2.87780687e-02,
#         -4.19691429e-02,  3.22576798e-02, -5.27030304e-02,
#          1.62959509e-02,  4.48643416e-02,  4.74955235e-03,
#         -9.29019041e-03, -1.02785252e-01,  2.15442199e-02,
#          6.97802082e-02, -9.34466370e-04, -6.69115037e-02,
#          6.46273866e-02, -2.56756395e-02,  6.15447313e-02,
#          8.82679820e-02, -7.84069598e-02,  7.50598439e-04,
#          7.13020116e-02,  1.10408626e-02, -5.07780835e-02,
#          6.67353943e-02, -1.11166321e-01,  1.75925717e-02,
#          5.48315458e-02,  2.89816018e-02,  4.31747064e-02,
#         -8.80346224e-02,  2.67310124e-02,  4.74298000e-02,
#          7.82820731e-02,  7.40151107e-02, -1.21026374e-01,
#          1.33357681e-02, -1.02837138e-01,  6.81054639e-03,
#         -4.78867367e-02, -1.55966002e-02, -5.17855249e-02,
#         -3.87281775e-02, -1.69230364e-02,  3.01935617e-03,
#          1.13085072e-04, -4.40406911e-02, -2.54628267e-02,
#         -6.52932078e-02,  3.14840674e-02,  3.92871676e-03,
#          7.39758462e-02,  4.81123030e-02, -2.98572443e-02,
#          3.32599282e-02, -7.31798112e-02,  2.02662796e-02,
#         -4.73465063e-02, -1.47034619e-02, -2.77814493e-02,
#         -1.17413074e-01, -1.70409996e-02, -6.54659271e-02,
#          2.04986446e-02,  1.70694366e-02,  1.62205286e-02,
#         -2.07417998e-02,  5.46512380e-03, -4.61992733e-02,
#          2.15653777e-02,  2.28040870e-02, -9.02607944e-03,
#          7.94480816e-02, -3.37869860e-02, -1.60870459e-02,
#         -3.62258255e-02, -1.85631169e-03, -1.77955609e-02,
#         -1.03896530e-02, -8.10404941e-02,  1.51103726e-02,
#         -3.31027135e-02, -3.97567786e-02, -3.14351693e-02,
#         -2.15179510e-02, -3.24279000e-03, -3.46101001e-02,
#          1.33152073e-02,  1.62141299e-33,  2.38010194e-02,
#         -2.97832862e-03, -4.67887055e-03,  3.50311920e-02,
#         -3.52302194e-02, -5.49819842e-02, -1.04468875e-02,
#          6.51908293e-02,  1.53511791e-02, -5.24341203e-02,
#          4.60851006e-02, -2.99135074e-02,  1.27912998e-01,
#         -2.05987301e-02,  1.32791951e-01,  1.89778709e-03,
#          8.86152906e-04,  6.22953586e-02,  4.34123650e-02,
#         -1.73100010e-02, -8.29504654e-02,  6.79753581e-03,
#         -3.83607186e-02, -1.25078121e-02, -1.02706604e-01,
#         -2.52419990e-02,  1.00722492e-01, -9.71158296e-02,
#          2.41713841e-02, -1.47717791e-02,  1.01248033e-01,
#         -4.19814438e-02,  7.02811219e-03,  8.43221322e-02,
#          2.20769551e-02,  1.11416496e-01, -1.50100002e-02,
#         -3.14286835e-02, -6.47336617e-02, -7.76570141e-02,
#          1.37149887e-02, -1.78768747e-02, -8.40700511e-03,
#          4.40597646e-02,  9.73404944e-03,  3.58225182e-02,
#          3.32848914e-02, -1.15692001e-02,  1.02646410e-01,
#          2.42907256e-02,  5.73435090e-02,  1.90249234e-02,
#          6.76007643e-02,  2.44636796e-02,  4.23678085e-02,
#         -6.44357642e-03, -7.69675821e-02,  4.30779159e-02,
#         -9.35100857e-03, -3.54530402e-02,  6.19097538e-02,
#          3.77410762e-02, -3.13298739e-02, -3.86825241e-02,
#          7.45965242e-02,  2.20139492e-02,  1.43580437e-02,
#         -8.21954384e-02, -2.65043434e-02,  5.73124997e-02,
#          8.85888760e-04,  7.55528212e-02,  1.94500145e-02,
#         -1.33778274e-01, -1.03393896e-02,  4.46064100e-02,
#         -4.99337725e-02, -4.78693172e-02, -3.51900305e-03,
#          2.18927837e-03, -1.11304618e-01,  3.54769193e-02,
#         -3.57679389e-02,  4.84392121e-02,  5.12832850e-02,
#          8.00464079e-02,  3.76714431e-02,  7.57757649e-02,
#         -6.62158709e-03, -2.49177944e-02,  2.06478722e-02,
#          6.81988224e-02, -2.40385178e-02,  2.32014395e-02,
#         -7.76809976e-02, -1.47742785e-09, -4.56025414e-02,
#          4.99582440e-02, -6.76657856e-02,  1.23908510e-02,
#          3.04796789e-02, -1.48877371e-02, -1.23246208e-01,
#          7.28519037e-02, -1.81398410e-02, -4.53802198e-02,
#         -2.22016200e-02, -2.68419515e-02, -6.59811795e-02,
#         -2.06950195e-02,  9.64099318e-02,  4.55779247e-02,
#         -7.41574541e-02,  2.54015811e-02,  1.30728120e-02,
#         -4.86320555e-02, -1.12930179e-01, -2.30336953e-02,
#          6.09849170e-02, -2.65561454e-02, -6.51061255e-03,
#         -3.84271257e-02,  5.53854480e-02, -4.40390344e-04,
#         -3.43972221e-02, -5.76672591e-02,  1.82032790e-02,
#          1.70044675e-02,  8.08115080e-02,  2.03661602e-02,
#          8.93914998e-02,  1.22860735e-02, -4.32989523e-02,
#          2.94773802e-02,  2.13414077e-02, -2.60855407e-02,
#          3.48033383e-02,  2.54917471e-03,  5.68764955e-02,
#          9.12172273e-02,  2.17070822e-02,  2.25198213e-02,
#         -7.94643257e-03, -4.32095118e-02,  7.02573657e-02,
#         -1.45519543e-02, -2.73095183e-02,  7.11484924e-02,
#         -1.50969643e-02,  7.65782222e-02, -2.72337403e-02,
#         -8.20313953e-03,  4.77764681e-02,  4.69712019e-02,
#          5.74430861e-02,  9.44849849e-03,  1.30807580e-02,
#         -7.38618197e-03, -9.56387073e-03, -1.21182390e-01],
#        [-6.82204962e-02,  1.46947606e-02,  3.36434841e-02,
#         -4.06606868e-02,  6.26801513e-03,  1.00073218e-01,
#          1.00420870e-01,  2.22128741e-02, -8.33382532e-02,
#         -2.77064573e-02,  1.97963025e-02, -6.28442224e-03,
#         -5.79247884e-02, -4.53975014e-02,  3.05687767e-02,
#          1.22403037e-02, -8.99791345e-02, -4.17013856e-04,
#         -7.33985901e-02,  3.88037041e-02,  2.34004874e-02,
#         -6.19219337e-03,  7.43054524e-02, -3.11783291e-02,
#         -3.50753814e-02,  7.08321109e-02,  4.89576943e-02,
#         -6.93913475e-02,  2.83233598e-02,  3.38510126e-02,
#          3.86980735e-02, -7.03666881e-02,  8.11271816e-02,
#         -2.07613148e-02, -6.49614036e-02,  1.77311879e-02,
#         -2.37153079e-02,  2.49453983e-03, -8.25171545e-03,
#         -1.47803538e-02, -4.37534302e-02,  1.88223869e-02,
#          6.14183359e-02,  9.42563117e-02, -2.06727447e-04,
#         -2.97542531e-02, -1.73812616e-03,  1.50431246e-02,
#          1.03014067e-01, -5.81575893e-02,  1.01687461e-02,
#         -7.58993998e-02,  2.07932084e-03,  9.23894718e-03,
#          7.25444360e-03,  4.16128244e-03,  9.05176438e-03,
#         -1.08275257e-01, -2.62734722e-02, -3.22191902e-02,
#          1.71036739e-02,  3.28746215e-02,  3.47496010e-02,
#          2.62719691e-02, -2.29102019e-02, -7.20702335e-02,
#          2.24707182e-03,  1.03952117e-01,  5.54375313e-02,
#          6.04192428e-02,  2.56895809e-03, -5.01140347e-03,
#         -3.59332971e-02, -5.47140464e-02, -4.30083238e-02,
#          8.71749893e-02, -7.77451843e-02, -3.86668779e-02,
#         -9.88830999e-02,  3.03698401e-03,  3.25499699e-02,
#         -5.80112636e-03,  3.14234048e-02, -2.67478023e-02,
#         -4.56935987e-02,  3.78013737e-02, -4.55775224e-02,
#         -6.53963909e-02,  2.02023592e-02,  4.08432633e-02,
#         -7.83035830e-02, -2.32568532e-02, -4.04186174e-02,
#         -2.93554016e-03, -6.08115122e-02, -1.85016058e-02,
#         -1.54762222e-02, -7.45376647e-02, -3.34477685e-02,
#          3.82386670e-02, -4.58282866e-02, -4.79436554e-02,
#          1.14831261e-01,  3.44838127e-02,  2.91243847e-03,
#         -9.35047716e-02,  3.68190818e-02,  6.33702278e-02,
#          1.20304655e-02, -2.10539158e-02,  5.19942679e-02,
#         -1.31739601e-02,  2.38421895e-02, -1.53651964e-02,
#          6.08601747e-03, -1.57611619e-03, -8.31748620e-02,
#         -6.25711456e-02,  2.25599930e-02, -6.64218441e-02,
#          3.69393937e-02,  7.94992521e-02,  1.44037802e-03,
#         -5.81071489e-02,  5.08746058e-02,  7.98034891e-02,
#          5.64604774e-02, -2.18101428e-34, -4.84336691e-04,
#          4.90642898e-02,  1.04275737e-02,  9.58605707e-02,
#          6.20175265e-02,  2.51779482e-02, -2.10516527e-02,
#         -4.36803289e-02, -4.43162583e-02, -5.60511239e-02,
#         -2.56652720e-02, -5.20954393e-02, -2.02356670e-02,
#          5.44124618e-02, -1.48172468e-01, -2.13144235e-02,
#         -5.08729778e-02,  2.80365590e-02,  1.63618550e-02,
#          1.13648642e-03, -1.35026248e-02, -2.58026477e-02,
#          2.06030998e-02, -4.06466126e-02, -1.88227296e-02,
#          5.66694289e-02,  5.81646487e-02, -6.24244697e-02,
#          6.28256872e-02,  2.09192913e-02,  4.97987829e-02,
#          6.67564124e-02, -1.75480232e-01, -1.04235068e-01,
#         -8.34935829e-02, -2.38824589e-03, -2.75744963e-02,
#         -9.07784179e-02,  4.38258946e-02,  9.54896063e-02,
#          3.02437767e-02, -4.69645821e-02,  2.26727501e-02,
#          2.57762126e-03,  5.63041773e-03,  7.86075816e-02,
#         -4.90085818e-02,  1.05376944e-01,  6.46237805e-02,
#          1.39651103e-02, -3.19869258e-02, -3.02071627e-02,
#         -8.48162454e-03, -1.35055445e-02, -7.12228715e-02,
#          4.40140627e-02,  1.28250103e-02, -2.00261697e-02,
#         -1.91209093e-02, -1.83708817e-02,  2.10512448e-02,
#         -8.64146873e-02, -1.65813938e-02,  3.20640914e-02,
#         -6.33996120e-03, -7.05928952e-02,  4.81029674e-02,
#         -3.85057554e-02,  9.43556875e-02,  6.63177818e-02,
#         -9.31928307e-02,  2.91735516e-03, -1.29153505e-02,
#          3.28292660e-02, -8.14130753e-02,  2.48606838e-02,
#          9.82945878e-03, -9.82451960e-02,  2.88239121e-02,
#          8.33573639e-02,  9.86412913e-03, -2.97953449e-02,
#          5.84908463e-02, -2.10044556e-03, -1.82389598e-02,
#          5.04754931e-02,  1.81700103e-02, -5.79610132e-02,
#         -1.68164551e-01,  3.91289368e-02,  9.09553468e-02,
#         -2.56137480e-03,  3.84007692e-02,  5.01101986e-02,
#          9.59843025e-03, -1.18301120e-34,  2.41032336e-02,
#          1.26109943e-02, -4.55290340e-02,  3.27495066e-03,
#          9.71235186e-02, -2.81165564e-03, -6.23151474e-02,
#          8.03479925e-03,  2.35564867e-03,  6.19163848e-02,
#         -3.63333859e-02,  2.06688102e-02,  1.09245759e-02,
#         -8.75497796e-03, -1.36059979e-02, -4.53669652e-02,
#          2.98238005e-02, -5.33771031e-02,  8.71519595e-02,
#         -1.19151473e-02,  1.98576245e-02, -5.05584255e-02,
#         -9.43113770e-03, -5.19089401e-03,  2.85349470e-02,
#         -9.95105132e-03,  3.42523567e-02,  5.31222522e-02,
#         -1.26603633e-01,  9.43523943e-02, -1.78287029e-02,
#         -4.49908338e-02,  3.87857971e-03,  5.03163189e-02,
#         -3.72604989e-02,  1.43550867e-02,  7.99116865e-02,
#         -1.97294587e-03,  3.26698013e-02,  3.09772249e-02,
#          5.57178818e-03,  3.29787210e-02, -3.56298871e-02,
#         -3.19773128e-04, -2.73889787e-02,  2.91978139e-02,
#          5.43983327e-03,  5.67256957e-02, -1.65103734e-01,
#          6.48626387e-02,  4.54308977e-03, -6.96163764e-03,
#         -3.11851054e-02, -9.23827216e-02, -2.43811142e-02,
#          1.29425824e-02, -5.63193187e-02, -2.03660037e-02,
#          5.36441877e-02,  5.49541935e-02, -9.19601023e-02,
#          3.61508094e-02,  5.06199077e-02, -6.80589257e-03,
#          2.62314733e-02, -1.44451065e-02, -2.81200446e-02,
#         -3.72112766e-02, -4.59736995e-02, -2.43915478e-03,
#          2.92911716e-02,  4.87365294e-03, -9.47670937e-02,
#          4.30424232e-03, -1.98548771e-02, -3.01720388e-02,
#          3.17306668e-02, -8.23592246e-02,  1.11447331e-02,
#          6.32280763e-03, -4.00434434e-02, -1.46827451e-03,
#         -2.02728827e-02,  5.10069281e-02,  5.30500561e-02,
#         -6.82831928e-02, -2.63125412e-02,  9.03712586e-03,
#         -2.15149317e-02,  1.61083359e-02, -7.00050741e-02,
#          6.54145777e-02, -5.50298765e-02,  3.26793231e-02,
#         -5.05747609e-02, -1.75617554e-09, -3.63093056e-02,
#          5.05105853e-02, -4.56463695e-02,  6.17400743e-02,
#          7.46562779e-02,  1.56219611e-02, -4.97736372e-02,
#          3.70769836e-02, -5.06488197e-02, -1.04359621e-02,
#          5.52421138e-02,  5.47689684e-02, -1.24498771e-03,
#          1.01524517e-01,  3.45370136e-02, -4.89070453e-02,
#         -1.70426276e-02,  5.94995841e-02, -1.23033814e-01,
#          1.23124933e-02, -1.88104901e-02,  2.68515144e-02,
#          6.85230494e-02, -1.21877249e-02, -3.14930119e-02,
#         -2.98581980e-02,  8.87479559e-02,  4.99137379e-02,
#         -8.62594321e-03,  5.55795655e-02, -6.28692284e-02,
#         -3.17486785e-02, -1.36259589e-02,  8.13663676e-02,
#          3.11077423e-02,  1.05503559e-01, -1.68258194e-02,
#         -3.85239609e-02,  8.43200684e-02,  1.83722656e-02,
#          7.40614831e-02, -7.02658445e-02,  1.01035098e-02,
#          1.13498829e-02, -8.58992897e-03, -8.65221247e-02,
#         -6.45637559e-03,  2.95525696e-02,  4.00159620e-02,
#         -5.97739331e-02, -1.33547829e-02,  1.41096413e-02,
#         -2.26223990e-02,  9.93330181e-02,  1.08485026e-02,
#         -2.30019707e-02,  6.29779994e-02,  7.90569857e-02,
#          1.50158741e-02,  4.67709675e-02, -3.14442441e-02,
#          1.73333734e-02, -2.82296520e-02, -1.04273595e-02]], dtype=float32)

# %%
pca.singular_values_ ** 2
# Out:
# array([1.523029  , 0.05495575], dtype=float32)

# %%
new = pca.transform(X)
new
# Out:
# array([[-0.26325727,  0.16821758],
#        [-0.28362614,  0.04722245],
#        [-0.2856641 , -0.13536549],
#        [-0.27115232, -0.07810844],
#        [ 1.1036998 , -0.00196614]], dtype=float32)

# %%
# sklearn ver
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))
plt.scatter(new[:,0],new[:,1], linewidths=10, color='blue')
# plt.xlim(-0.25, 0.25)
# plt.ylim(-0.25, 0.25)
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
# plt.title("Word Embedding Space",size=20)
vocab=op
for i, word in enumerate(vocab):
  plt.annotate(word,xy=(new[i,0],new[i,1]))

# %% [markdown]
# ### データの読み込み

# %%
data = pd.read_excel("domestic.xlsx")
data
# Out:
#             調査    賛成  どちらかといえば賛成  どちらかといえば反対    反対  わからない
# 0    1979年5月調査  29.1        41.0        18.3   4.5    7.1
# 1   1992年11月調査  19.8        35.8        26.4  11.9    6.1
# 2    1997年9月調査  17.9        34.0        26.9  16.7    4.6
# 3    2002年7月調査  12.8        30.5        29.4  21.7    5.6
# 4   2004年11月調査  11.0        30.2        29.5  24.2    5.0
# 5    2007年8月調査  12.0        27.8        30.7  26.2    3.2
# 6   2009年10月調査   9.5        27.8        32.0  26.6    4.0
# 7   2012年10月調査  12.4        36.0        30.4  18.4    2.8
# 8    2014年8月調査  11.2        32.0        34.2  17.4    5.1
# 9    2016年9月調査   8.3        28.7        37.0  21.5    4.5
# 10   2019年9月調査   6.5        24.6        38.5  24.9    5.5

# %%
# data = pd.read_excel("domestic_.xlsx")
# data

# %%
data.iloc[0, 1:]
# Out:
# 賛成            29.1
# どちらかといえば賛成    41.0
# どちらかといえば反対    18.3
# 反対             4.5
# わからない          7.1
# Name: 0, dtype: object

# %%
year1979 = pd.DataFrame({data.iloc[0, 0] : data.iloc[0, 1:]})
year1979['pot'] = -np.log(year1979['1979年5月調査'].astype(np.float64)/100)
# type(np.log(year1979.iloc[0,0]/100))
year1979
# Out:
#            1979年5月調査       pot
# 賛成              29.1  1.234432
# どちらかといえば賛成      41.0  0.891598
# どちらかといえば反対      18.3  1.698269
# 反対               4.5  3.101093
# わからない            7.1  2.645075

# %% [markdown]
# ##### 1979年のみ

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.cm as cm

# set up the figure and axes
fig = plt.figure(figsize=(6, 6), dpi=220)
ax2 = fig.add_subplot(111, projection='3d')

ax2.scatter(neww_X[:,0],neww_X[:,1], [0,0,0,0,0], linewidths=10,color='yellow')
# ax2.xlim(-0.25, 0.25)
# ax2.ylim(-0.25, 0.25)
# ax2.xlabel("PC1",size=15)
# ax2.ylabel("PC2",size=15)

jp = ['賛成', 'やや賛成', 'やや反対', '反対', 'わからない']
for i, word in enumerate(jp):
  ax2.text(neww_X[i,0]+0.01, neww_X[i,1]+0.01, 0, word, zdir=None)

# bar graph code
x, y, z = neww_X[:,0], neww_X[:,1], year1979.iloc[:, 0].astype(np.float64).tolist()
# print(x, y, z)
top = z
bottom = np.zeros_like(top)
width = 0.01
depth = 0.01
ax2.bar3d(x, y, bottom, width, depth, top, shade=False)
# ax2.set_title('支持者数')

# plt.xticks([-0.2, -0.1, 0, 0.1, 0.2])
# plt.yticks([-0.2, -0.1, 0, 0.1, 0.2])

ax2.set_xlabel('PC1')
ax2.set_ylabel('PC2')
ax2.set_zlabel("\n回答者の割合 (%)")
ax2.set_title("1979年5月調査",size=15)

plt.savefig("5_domestic_1979.png")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.cm as cm

# set up the figure and axes
fig = plt.figure(figsize=(6, 6)) #, dpi=220)
ax2 = fig.add_subplot(111, projection='3d')

ax2.scatter(neww_X[:,0],neww_X[:,1], [0,0,0,0,0], linewidths=10,color='yellow')
# ax2.xlim(-0.25, 0.25)
# ax2.ylim(-0.25, 0.25)
# ax2.xlabel("PC1",size=15)
# ax2.ylabel("PC2",size=15)

jp = ['賛成', 'やや賛成', 'やや反対', '反対']
for i, word in enumerate(jp):
  ax2.text(neww_X[i,0]+0.01, neww_X[i,1]+0.01, 0, word, zdir=None)

# bar graph code
x, y, z = neww_X[:,0], neww_X[:,1], year1979.iloc[:, 0].astype(np.float64).tolist()
# print(x, y, z)
top = z
bottom = np.zeros_like(top)
width = 0.01
depth = 0.01
ax2.bar3d(x, y, bottom, width, depth, top, shade=False)
# ax2.set_title('支持者数')

## surface plot code
# border condition
dum = [-0.6, 0.6, -0.6, 0.6]
dumy = [-0.6, 0.6, 0.6, -0.6]

xx = neww_X[:,0].tolist()
yy = neww_X[:,1].tolist()

for l in range(len(dum)):
    xx.append(dum[l]) 
    yy.append(dumy[l])

zz = 10*year1979.iloc[:, 1]
zz = zz.to_list()
for m in range(len(dum)):
    zz.append(-np.log(1/100))
    
X, Y, Z = xx, yy, zz

points = np.array([X, Y]).T

# # create a grid of coordinates between the minimum and
# # maximum of your X and Y. 50j indicates 50 discretization
# # points between the minimum and maximum.
X_grid, Y_grid = np.mgrid[-0.6:0.6:100j, -0.6:0.6:100j]
# # interpolate your values on the grid defined above
Z_grid = griddata(points, Z, (X_grid, Y_grid), method='cubic')

ax2.plot_surface(X_grid, Y_grid, Z_grid, cmap=cm.coolwarm, 
                       linewidth=0, antialiased=True, alpha=.6)

ax2.view_init(elev= 25, azim=170, roll=0)

# plt.xticks([-0.2, -0.1, 0, 0.1, 0.2])
# plt.yticks([-0.2, -0.1, 0, 0.1, 0.2])

ax2.set_xlabel('PC1')
ax2.set_ylabel('PC2')
ax2.set_zlabel("\n回答者の割合 (%), \nポテンシャル*10")
ax2.set_title("1979年5月調査",size=15)

plt.savefig("5_domestic_pot_1979.png")
plt.show()

# %% [markdown]
# ### まとめて可視化

# %%
data
# Out:
#             調査    賛成  どちらかといえば賛成  どちらかといえば反対    反対  わからない
# 0    1979年5月調査  29.1        41.0        18.3   4.5    7.1
# 1   1992年11月調査  19.8        35.8        26.4  11.9    6.1
# 2    1997年9月調査  17.9        34.0        26.9  16.7    4.6
# 3    2002年7月調査  12.8        30.5        29.4  21.7    5.6
# 4   2004年11月調査  11.0        30.2        29.5  24.2    5.0
# 5    2007年8月調査  12.0        27.8        30.7  26.2    3.2
# 6   2009年10月調査   9.5        27.8        32.0  26.6    4.0
# 7   2012年10月調査  12.4        36.0        30.4  18.4    2.8
# 8    2014年8月調査  11.2        32.0        34.2  17.4    5.1
# 9    2016年9月調査   8.3        28.7        37.0  21.5    4.5
# 10   2019年9月調査   6.5        24.6        38.5  24.9    5.5

# %%
year1979 = pd.DataFrame({data.iloc[1, 0] : data.iloc[1, 1:]})
year1979['pot'] = -np.log(year1979.iloc[:, 0].astype(np.float64)/100)
# type(np.log(year1979.iloc[0,0]/100))
year1979
# Out:
#            1992年11月調査       pot
# 賛成               19.8  1.619488
# どちらかといえば賛成       35.8  1.027222
# どちらかといえば反対       26.4  1.331806
# 反対               11.9  2.128632
# わからない             6.1  2.796881

# %%
fig, axes = plt.subplots(3, 4, figsize=(15,15), subplot_kw={'projection': '3d'})

h = 0

for i in range(3):
    for j in range(4):

        axes[i][j].scatter(neww_X[:,0], neww_X[:,1], [0,0,0,0,0], linewidths=1,color='blue')
        vocab=op
        for k, word in enumerate(vocab):
            axes[i][j].text(neww_X[k,0], neww_X[k,1], 0, word[:10], zdir=None)

        # calculate potential
        year1979 = pd.DataFrame({data.iloc[h, 0] : data.iloc[h, 1:]})
        year1979['pot'] = -np.log(year1979.iloc[:, 0].astype(np.float64)/100)

        # bar graph code
        x, y, z = neww_X[:,0], neww_X[:,1], year1979.iloc[:, 0].astype(np.float64).tolist()
        
        top = z
        bottom = np.zeros_like(top)
        width = 0.01
        depth = 0.01
        axes[i][j].bar3d(x, y, bottom, width, depth, top, shade=True)
        axes[i][j].set_title(data.iloc[h, 0])
        h += 1

        # # surface plot code

        dum = [-0.6, 0.6, -0.6, 0.6]
        dumy = [-0.6, 0.6, 0.6, -0.6]

        xx = neww_X[:,0].tolist()
        yy = neww_X[:,1].tolist()

        for l in range(len(dum)):
            xx.append(dum[l]) 
            yy.append(dumy[l])

        zz = 10*year1979.iloc[:, 1]
        zz = zz.to_list()
        for m in range(len(dum)):
            zz.append(-np.log(1/100))
        
        X, Y, Z = xx, yy, zz

        points = np.array([X, Y]).T

        # # create a grid of coordinates between the minimum and
        # # maximum of your X and Y. 50j indicates 50 discretization
        # # points between the minimum and maximum.
        X_grid, Y_grid = np.mgrid[-0.6:0.6:100j, -0.6:0.6:100j]
        # # interpolate your values on the grid defined above
        Z_grid = griddata(points, Z, (X_grid, Y_grid), method='cubic')

        axes[i][j].plot_surface(X_grid, Y_grid, Z_grid, cmap=cm.coolwarm, 
                            linewidth=0, antialiased=True, alpha=.7)

        # axes[i][j].set_ylim(-0.5, 0.5)

        axes[i][j].view_init(elev= 25, azim=280, roll=0)

        axes[i][j].set_xlabel("PC1")
        axes[i][j].set_ylabel("PC2")
        axes[i][j].set_zlabel("Z (%)")

        if h == 11:
            break

plt.savefig("5_domestic_pot_all.png")
