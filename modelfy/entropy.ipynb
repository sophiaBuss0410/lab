# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Entropy as a function of probability --------
# random sample for probabilities
p = np.arange(0.01,1,0.01)

# compute binary entropy
entropy = -p*np.log2(p) - (1-p)*np.log2(1-p)

# visualize
plt.plot(p,entropy,linewidth=4,color='r',alpha=0.5)
plt.ylabel('Entropy H(p)', fontsize=18)
plt.xlabel('Probability p', fontsize=18)
plt.tick_params(labelsize=18)
plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Entropy as a function of probability --------
# random sample for probabilities
p = np.arange(0.01,1,0.01)

# compute binary entropy
entropy = -p*np.log2(p) - (1-p)*np.log2(1-p)

# visualize
plt.plot(p,entropy,linewidth=4,color='r',alpha=0.5)

x_f = 0.1
# x_f = 0.097
x_m = 1-x_f

h_f = -x_f*np.log2(x_f) - (1-x_f)*np.log2(1-x_f)
h_m = -x_m*np.log2(x_m) - (1-x_m)*np.log2(1-x_m)
print(h_f)

plt.scatter(x_f, h_f, label="female")
plt.scatter(x_m, h_m, label="male")
plt.ylabel('Entropy H(p)', fontsize=18)
plt.xlabel('Probability p', fontsize=18)
plt.legend()
plt.tick_params(labelsize=18)
plt.tight_layout()
# Out:
# 0.4689955935892812

# %%
data = [[0.456, 0.544, 637000], 
        [0.223, 0.777, 9559],
        [0.198, 0.802, 3060]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Entropy as a function of probability --------
# random sample for probabilities
p = np.arange(0.01,1,0.01)

# compute conditional entropy
entropy = -p*np.log2(p) - (1-p)*np.log2(1-p)

# visualize
plt.plot(p,entropy,linewidth=4,color='r',alpha=0.5)

x_f = 0.223
# x_f = 0.097
x_m = 1-x_f

h_f = -x_f*np.log2(x_f) - (1-x_f)*np.log2(1-x_f)
h_m = -x_m*np.log2(x_m) - (1-x_m)*np.log2(1-x_m)
print(h_f)

plt.scatter(x_f, h_f, label="female")
plt.scatter(x_m, h_m, label="male")
plt.ylabel('Entropy H(p)', fontsize=18)
plt.xlabel('Probability p', fontsize=18)
plt.legend()
plt.tick_params(labelsize=18)
plt.tight_layout()
# Out:
# 0.7656077043870684
